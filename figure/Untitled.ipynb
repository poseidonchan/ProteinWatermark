# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extended list of tokens representing amino acids
tokens = ['A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']

# Assuming a uniform distribution, each amino acid has an equal probability
uniform_probability = 1 / len(tokens_extended)
probabilities = [uniform_probability] * len(tokens_extended)

# %%
sns.set(style="whitegrid")

# Creating the plot with seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x=tokens, y=probabilities, color='#FF653A')

# Adding labels and title for clarity
plt.xlabel('Tokens (Amino Acids)', fontsize=14)
plt.ylabel('Probability', fontsize=14)
plt.title('Distribution of Token Probabilities (Uniform Distribution) with Seaborn', fontsize=16)

# Display the plot
plt.show()
